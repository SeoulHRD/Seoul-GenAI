# %%
# 패키지 로딩하기 : 패키지를 메모리에 올리는 기능
import matplotlib.pyplot as plt
import numpy             as np
import pandas            as pd
import seaborn           as sns

# %%
# 그래프의 한글 깨짐 처리
plt.rcParams["font.family"] = "Malgun Gothic"

# %%
# 파일 경로
file_path = "D:/SEOUL/2025년 감염병환자 발생 현황(서울시, 2025.1.1~9.17.) 수정 2.xlsx"

# 엑셀 파일 읽기
seoul = pd.read_excel(file_path)

# 데이터 확인
print(seoul.head())
# Out:
#   자치구명   합계  수두  홍역  콜레라  장티푸스  파라티푸스  세균성이질  장출혈성대장균감염증  A형간염  ...  웨스트나일열  \
# 0  강남구  549   1   0    0     0      1      2           7    42  ...       0
# 1  강동구  858   1   0    0     0      0      4           7    29  ...       1
# 2  강북구  196   0   0    0     0      1      3           4     9  ...       0
# 3  강서구  506   0   0    1     1      0      5          19    28  ...       0
# 4  관악구  414   0   0    0     1      1      6           3    12  ...       0
#
#    라임병  진드기매개뇌염  유비저  치쿤구니야열  중증열성혈소판감소증후군(SFTS)  지카바이러스감염증  매독  매독(선천성)  @엠폭스
# 0    0        0    0       1                   0         24   1        1     1
# 1    0        0    0       0                   0         18   0        0     0
# 2    0        0    0       0                   0         12   1        0     0
# 3    0        0    0       0                   0         20   0        0     0
# 4    0        0    0       1                   0         48   0        0     0
#
# [5 rows x 51 columns]

# %%
# 데이터 정보(Information) 보기
print(seoul.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 51 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   자치구명                                  25 non-null     object
#  1   합계                                    25 non-null     int64
#  2   수두                                    25 non-null     int64
#  3   홍역                                    25 non-null     int64
#  4   콜레라                                   25 non-null     int64
#  5   장티푸스                                  25 non-null     int64
#  6   파라티푸스                                 25 non-null     int64
#  7   세균성이질                                 25 non-null     int64
#  8   장출혈성대장균감염증                            25 non-null     int64
#  9   A형간염                                  25 non-null     int64
#  10  백일해                                   25 non-null     int64
# ...

# %%
# DataFrame : 행과 열로 되어 있는 데이터, 2차원 구조
# RangeIndex: 92606 : 행의 개수
# total 12 columns  : 열(Column)의 개수, 변수(Variable), Feature(X), Label or Target(y)
# 0 : 첫 번째
# Null : 값이 없는 셀(빈 셀), Missing Value(결측치, 결측값)
# Non-Null : 값이 있는 셀

# Missing Value 탐지 및 처리
# (1) 삭제한다. 행 기준
# (2) 대체(Imputation)한다. 다른 특정한 값으로 변경, 평균, 중위수, ...

# Dtype : Type of Data : 데이터의 유형, 값이 무엇으로 되어 있는가?
# Object : 문자
# int    : 숫자(정수, integer)
# float  : 숫자(실수, real number)
# memory usage: 8.5+ MB : seoul 데이터가 메모리를 차지하는 양
# 기본 : 8GB = 8000MB

# %%
# 데이터 전처리(Data Pre-Processing, 데이터 핸들링)

# %%
# 탐색적 데이터 분석

# %% [markdown]
# 1. 범주형 데이터 분석 : 1개의 열
# - 표 = 빈도표(Frequency Table) : 빈도, 백분율
# - 데이터 시각화(Data Visualization) : 막대그래프(Bar Chart), 원그래프(비추)

# %%
# 파일 경로 (업로드된 파일명 반영)
file_path = "2025년 감염병환자 발생 현황(서울시, 2025.1.1~9.17.) 수정 2.xlsx"

# 데이터 불러오기
df = pd.read_excel(file_path, sheet_name="sheet")

# 자치구별 감염병 합계 계산 (자치구명을 제외한 나머지 컬럼 합산)
df["합계"] = df.drop(columns=["자치구명"]).sum(axis=1)

# 결과 정리
result = df[["자치구명", "합계"]]

# 출력
print(result)

# 필요하다면 엑셀/CSV 저장
# result.to_excel("서울시_자치구별_감염병합계.xlsx", index=False)
# result.to_csv("서울시_자치구별_감염병합계.csv", index=False, encoding="utf-8-sig")
# Out:
#     자치구명    합계
# 0    강남구   549
# 1    강동구   858
# 2    강북구   196
# 3    강서구   506
# 4    관악구   414
# 5    광진구   269
# 6    구로구  1002
# 7    금천구   218
# 8    노원구   640
# 9    도봉구   212
# 10  동대문구   789
# 11   동작구   279
# 12   마포구   150
# 13  서대문구   678
# 14   서초구   508
# 15   성동구   498
# 16   성북구   865
# 17   송파구  1002
# 18   양천구   583
# 19  영등포구   927
# 20   용산구   173
# 21   은평구   706
# 22   종로구   401
# 23    중구   108
# 24   중랑구   305

# %%
# 파일 경로 (업로드한 파일명 반영)
file_path = "2025년 감염병환자 발생 현황(서울시, 2025.1.1~9.17.) 수정 2.xlsx"

# 데이터 불러오기
df = pd.read_excel(file_path, sheet_name="sheet")

# 자치구별 감염병 합계 계산
df["합계"] = df.drop(columns=["자치구명"]).sum(axis=1)

# 결과 정리
result = df[["자치구명", "합계"]]

# 막대그래프 시각화
plt.figure(figsize=(14, 8))
plt.bar(result["자치구명"], result["합계"])

# 그래프 제목 및 레이블
plt.title("서울시 25개 자치구별 감염병 환자 발생 합계 (2025.1.1~9.17.)", fontsize=16)
plt.xlabel("자치구", fontsize=12)
plt.ylabel("감염병 환자 발생 합계", fontsize=12)

# x축 글자 겹침 방지
plt.xticks(rotation=45)

# 그리드 추가
plt.grid(axis="y", linestyle="--", alpha=0.7)

# 그래프 출력
plt.tight_layout()
plt.show()

# %%
### 2. 수치형 데이터 분석 : 1개의 열
- 표 = 빈도표 : 구간의 빈도, 백분율
- 데이터 시각화 : 히스토그램, 상자그림, 바이올린
- 기술통계량 = 요약통계량

# %%
# 파일 경로 (업로드한 파일명 반영)
file_path = "2025년 감염병환자 발생 현황(서울시, 2025.1.1~9.17.) 수정 2.xlsx"

# 데이터 불러오기
df = pd.read_excel(file_path, sheet_name="sheet")

# A형간염 자치구별 발생 현황
a_hepatitis = df[["자치구명", "A형간염"]]

# 평균 계산
mean_value = a_hepatitis["A형간염"].mean()

# 출력
print("자치구별 A형간염 발생 환자 수:")
print(a_hepatitis)
print("\n전체 평균 A형간염 발생 환자 수:", mean_value)
# Out:
# 자치구별 A형간염 발생 환자 수:
#     자치구명  A형간염
# 0    강남구    42
# 1    강동구    29
# 2    강북구     9
# 3    강서구    28
# 4    관악구    12
# 5    광진구     9
# 6    구로구    18
# 7    금천구     7
# 8    노원구    21
# 9    도봉구    16
# 10  동대문구    18
# 11   동작구    12
# 12   마포구    17
# 13  서대문구    16
# 14   서초구    34
# 15   성동구    12
# 16   성북구    23
# 17   송파구    29
# 18   양천구    34
# 19  영등포구    26
# 20   용산구    13
# 21   은평구    24
# 22   종로구     4
# 23    중구     3
# 24   중랑구    14
#
# 전체 평균 A형간염 발생 환자 수: 18.8

# %%
# 파일 경로 (업로드한 파일명 반영)
file_path = "2025년 감염병환자 발생 현황(서울시, 2025.1.1~9.17.) 수정 2.xlsx"

# 데이터 불러오기
df = pd.read_excel(file_path, sheet_name="sheet")

# A형간염 자치구별 발생 현황
a_hepatitis = df[["자치구명", "A형간염"]]

# 평균 계산
mean_value = a_hepatitis["A형간염"].mean()

# 막대그래프 시각화
plt.figure(figsize=(14, 8))
plt.bar(a_hepatitis["자치구명"], a_hepatitis["A형간염"], color="skyblue", label="자치구별 환자 수")

# 평균선 추가
plt.axhline(mean_value, color="red", linestyle="--", linewidth=2, label=f"평균 ({mean_value:.1f})")

# 그래프 제목 및 레이블
plt.title("서울시 자치구별 A형간염 발생 환자 수 (2025.1.1~9.17.)", fontsize=16)
plt.xlabel("자치구", fontsize=12)
plt.ylabel("A형간염 발생 환자 수", fontsize=12)

# x축 글자 겹침 방지
plt.xticks(rotation=45)

# 범례 추가
plt.legend()

# 그리드 추가
plt.grid(axis="y", linestyle="--", alpha=0.7)

# 그래프 출력
plt.tight_layout()
plt.show()

# %%
# 파일 경로 (업로드한 파일명 반영)
file_path = "2025년 감염병환자 발생 현황(서울시, 2025.1.1~9.17.) 수정 2.xlsx"

# 데이터 불러오기
df = pd.read_excel(file_path, sheet_name="sheet")

# A형간염 발생 환자수 데이터 추출
a_hepatitis = df["A형간염"]

# 시각화: 히스토그램, 상자그림, 바이올린플롯
plt.figure(figsize=(18, 5))

# 1. 히스토그램
plt.subplot(1, 3, 1)
plt.hist(a_hepatitis, bins=10, color="skyblue", edgecolor="black")
plt.title("A형간염 발생 환자수 분포 (히스토그램)")
plt.xlabel("환자수")
plt.ylabel("빈도")

# 2. 상자그림(Boxplot)
plt.subplot(1, 3, 2)
sns.boxplot(y=a_hepatitis, color="lightgreen")
plt.title("A형간염 발생 환자수 (상자그림)")
plt.ylabel("환자수")

# 3. 바이올린플롯(Violin plot)
plt.subplot(1, 3, 3)
sns.violinplot(y=a_hepatitis, color="lightcoral")
plt.title("A형간염 발생 환자수 (바이올린플롯)")
plt.ylabel("환자수")

# 레이아웃 정리
plt.tight_layout()
plt.show()
# Out:
# C:\Users\NT551\AppData\Local\Temp\ipykernel_9592\783533952.py:33: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   plt.tight_layout()
# C:\Users\NT551\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 파일 경로 (업로드한 파일명 반영)
file_path = "2025년 감염병환자 발생 현황(서울시, 2025.1.1~9.17.) 수정 2.xlsx"

# 데이터 불러오기
df = pd.read_excel(file_path, sheet_name="sheet")

# A형간염 자치구별 발생 현황
a_hepatitis = df[["자치구명", "A형간염"]]

# 산점도 시각화
plt.figure(figsize=(14, 8))
plt.scatter(range(len(a_hepatitis)), a_hepatitis["A형간염"], color="blue", s=80, alpha=0.7)

# x축을 자치구명으로 대체
plt.xticks(range(len(a_hepatitis)), a_hepatitis["자치구명"], rotation=45)

# 그래프 제목 및 레이블
plt.title("서울시 자치구별 A형간염 발생 환자 수 (산점도)", fontsize=16)
plt.xlabel("자치구", fontsize=12)
plt.ylabel("A형간염 발생 환자 수", fontsize=12)

# 격자 추가
plt.grid(True, linestyle="--", alpha=0.6)

# 그래프 출력
plt.tight_layout()
plt.show()

# %%
# 파일 경로 (업로드한 파일명 반영)
file_path = "2025년 감염병환자 발생 현황(서울시, 2025.1.1~9.17.) 수정 2.xlsx"

# 데이터 불러오기
df = pd.read_excel(file_path, sheet_name="sheet")

# 1. 자치구별 전체 감염병 합계
df["합계"] = df.drop(columns=["자치구명"]).sum(axis=1)

plt.figure(figsize=(14, 8))
plt.bar(df["자치구명"], df["합계"], color="skyblue")
plt.title("서울시 자치구별 전체 감염병 환자 발생 합계 (2025.1.1~9.17.)", fontsize=16)
plt.xlabel("자치구", fontsize=12)
plt.ylabel("환자 발생 합계", fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# 2. 자치구별 감염병 종류별 스택형 막대그래프
diseases = df.drop(columns=["자치구명", "합계"])

plt.figure(figsize=(16, 10))
bottom_values = [0] * len(df)

for col in diseases.columns:
    plt.bar(df["자치구명"], df[col], bottom=bottom_values, label=col)
    bottom_values = [i + j for i, j in zip(bottom_values, df[col])]

plt.title("서울시 자치구별 감염병 환자 발생 현황 (스택형 막대그래프)", fontsize=16)
plt.xlabel("자치구", fontsize=12)
plt.ylabel("환자 발생 수", fontsize=12)
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")  # 범례를 그래프 밖으로
plt.tight_layout()
plt.show()

# %%
# 파일 경로 (업로드한 파일명 반영)
file_path = "2025년 감염병환자 발생 현황(서울시, 2025.1.1~9.17.) 수정 2.xlsx"

# 데이터 불러오기
df = pd.read_excel(file_path, sheet_name="sheet")

# 전체 감염병 합계 계산
df["합계"] = df.drop(columns=["자치구명"]).sum(axis=1)

# 산점도 시각화
plt.figure(figsize=(10, 7))
plt.scatter(df["합계"], df["A형간염"], color="blue", alpha=0.7, s=80)

# 각 점에 자치구명 표시
for i, txt in enumerate(df["자치구명"]):
    plt.text(df["합계"][i] + 5, df["A형간염"][i] + 0.5, txt, fontsize=8)

# 그래프 제목 및 레이블
plt.title("서울시 자치구별 전체 감염병 환자수 vs A형간염 환자수 (산점도)", fontsize=14)
plt.xlabel("전체 감염병 환자수 합계", fontsize=12)
plt.ylabel("A형간염 환자수", fontsize=12)

# 격자 추가
plt.grid(True, linestyle="--", alpha=0.6)

# 그래프 출력
plt.tight_layout()
plt.show()
